# %% [markdown]
# <a href="https://colab.research.google.com/github/RitukumariBE/AI-ML/blob/main/AI_%26_ML_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tentative Course Plan

# %% [markdown]
# 1. Python Essentials --> 12
# 2. Python for AI & ML-->12
# 3. SQL for ML & AI -> Structured Query Language --> 18
# 4.NumPy --> Python Library for numerical Python --> 6
# 5. EDA using Pandas --> Efficiency deal with Tabular data using Python --> 12
# 6. Data Visualization using Python --> Matplotlib,Seaborn --> 6
# 7. Probability & Statistics --> 12
# 8. Classical ML --> Classification ,Regression --> 12
# 9. Deep Learning --> Neural Networks --> 12
# 10. GenAI & Prompt Engineering --> LLM, Frameworks for Prompt Engineering --> 16
# 11. RAG,Agents,MCP --> 16
# 12. Project & Deployment--> 4-5

# %% [markdown]
# # Important Terminologies

# %%
# Algorithm --> step by step instructions to solve any problem
# Programming --> giving instructions and interacting with the Computer
# Programming --> is a way of writing these instructions in a language that the computer understands.
# Programming Languages --> C,C++,Python,Java,Javascript ...
# Why Python ?
# 1. easiest to understand --> programmer friendly
# 2. Rich in libraries --> AI,ML,Web Dev,Automation..

# Hello world program --> C++ and Python

# C++ :
# #include<iostream >
# using namespace std ;

# int main(){
#     cout << "Hello World";
# }

# Python:
# print("Hello World")

# "Apple is Aditya Jain an eating"
# "Aditya Jain is eating an apple"

# What is Syntax ?
# Grammatical rules for that particular programming language.

# Why Google Colab Notebook ?
# 1. No installation
# 2. Free
# 3. Runs in Browser
# 4. Used across industry

# Notebook Cells
# Notebook is made of multiple cells

# %% [markdown]
# # Basics of Python Programming

# %%
print("Hello World !")
# Out:
# Hello World !

# %%
print("Welcome to Python")
# Out:
# Welcome to Python

# %%
# for multiple line
print("A")
print("B")
print("c")
# Out:
# A
# B
# c

# %%
print("A","B","C")
# when we print multiple things with comma it gets automatically space seperated
# Out:
# A B C

# %%
print(100)
# Out:
# 100

# %%
print(3+5)
# Out:
# 8

# %%
print(5-3)
# Out:
# 2

# %%
print(4*2)
# we can write a mathematical operations in print function and it give output
# Out:
# 8

# %%
print(4/2)
# Out:
# 2.0

# %%
print("3 + 2")
# quotes ke andar as a string jata h
# Out:
# 3 + 2

# %% [markdown]
# # H.W.

# %%
# what will be printed ?
# print(10)

# Ans : 10

# %%
# Guess the Output ?
# print (5 + 3)

# Ans : 8

# %%
print("thanks ! Hope it was useful:")
# Out:
# thanks ! Hope it was useful:
